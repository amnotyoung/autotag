# %% [markdown]
# # 🎯 KOICA TAG v3.1 - 예시 복사 방지 강화
#
# **🔧 v3.1 핵심 개선**:
# 1. ✅ **예시 복사 방지**: 형식 가이드로 변경, 구체적 내용 제거
# 2. ✅ **명시적 지시 강화**: "태양광, 디젤 등 예시 내용 복사 금지"
# 3. ✅ **검증 로직 추가**: 예시 키워드 검출 및 경고
# 4. ✅ **실제 문서 강조**: 참고 문서에서 발견한 내용만 사용
#
# **해결된 문제**:
# - ❌ 예시 내용(태양광, 디젤) 복사 → ✅ 실제 PDF 문서 분석
# - ❌ 엉뚱한 내용 출력 → ✅ 문서에 있는 내용만 분석
#
# ---

# %%
# GPU 확인
import torch
assert torch.cuda.is_available(), "❌ GPU 런타임이 아닙니다! Runtime → Change runtime type → GPU로 변경하세요"
print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f}GB")

# %%
# 필요한 패키지 설치
print("📦 패키지 설치 중...")
# !pip install -q pdfplumber gradio sentence-transformers huggingface-hub
# !pip install -q llama-cpp-python --extra-index-url https://abetlen.github.io/llama-cpp-python/whl/cu121
# !pip install -q pandas numpy
print("✅ 설치 완료!")

# %%
# GitHub에서 최신 v3.1 코드 다운로드
print("📥 v3.1 코드 다운로드 중...")
# !wget -q https://raw.githubusercontent.com/amnotyoung/autotag/claude/fix-solar-analysis-rainy-season-011CUv6NG6frc4X4LBy2vEBd/autotag.py -O autotag_v31.py

# 설치 명령 제거 (이미 위에서 설치했으므로)
with open('autotag_v31.py', 'r', encoding='utf-8') as f:
    code = f.read()

# !pip 명령어 라인 제거
lines = code.split('\n')
filtered_lines = []
skip_until_blank = False

for i, line in enumerate(lines):
    # 패키지 설치 부분 건너뛰기
    if '!pip install' in line:
        skip_until_blank = True
        continue
    if skip_until_blank:
        if line.strip() == '' or 'print' in line:
            skip_until_blank = False
        continue
    filtered_lines.append(line)

# 수정된 코드 저장
with open('autotag_v31_clean.py', 'w', encoding='utf-8') as f:
    f.write('\n'.join(filtered_lines))

print("✅ 코드 준비 완료!")

# %%
# v3.1 실행
print("🚀 KOICA TAG v3.1 시작...")
# %run autotag_v31_clean.py

# %% [markdown]
# ---
#
# ## ℹ️ 사용 방법
#
# 1. 위 셀을 순서대로 실행 (Shift + Enter)
# 2. Gradio 인터페이스가 열리면 PDF 업로드
# 3. 자동으로 TAG 분석 시작
# 4. 분석 완료 후 TXT/HTML 다운로드 가능
#
# ## 🔧 v3.1 개선사항
#
# - **예시 복사 방지**: AI가 형식 예시를 그대로 복사하던 문제 해결
# - **실제 문서 분석**: 업로드한 PDF의 실제 내용만 분석
# - **검증 강화**: 예시 키워드(태양광, 디젤 등) 검출 시 경고
#
# ## ⚠️ 참고사항
#
# - **GPU 런타임 필수**: Runtime → Change runtime type → GPU
# - 첫 실행 시 모델 다운로드로 3-5분 소요
# - 분석 시간: 30-50페이지 기준 약 5-10분
#
# ## 🐛 문제 해결
#
# - **GPU 에러**: Runtime → Change runtime type → GPU 확인
# - **패키지 에러**: 첫 번째 셀부터 다시 실행
# - **메모리 에러**: Runtime → Restart runtime 후 재시작
